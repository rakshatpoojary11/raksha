# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshatpoojary11/raksha/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'first':['aryan','rohan','riya','yash','siddini'],
    'lastname':['singh','agarwal','shah','batia','khan'],
    'type':['full_time employee','intern','full_time employee','part_time employee','full_time employee'],
    'department':['administration','technical','administration','technical','technical'],
    'yoe':[2,3,5,7,6],
    'salary':[20000,5000,10000,20000,4000]
}
df=pd.DataFrame(data)
print(df)
table=pd.pivot_table(df,index=['type','department'],values='salary',aggfunc=['mean'])
print(table)
table1=pd.pivot_table(df,index=['type','department'],values='salary',aggfunc=['mean','sum'])
print(table1)
table2=pd.pivot_table(df,index=['type'],values='salary',aggfunc=['count'])
print(table2)
table3=pd.pivot_table(df,index=['type'],values='salary',aggfunc=['std'])
print(table3)
# Out:
#      first lastname                type      department  yoe  salary
# 0    aryan    singh  full_time employee  administration    2   20000
# 1    rohan  agarwal              intern       technical    3    5000
# 2     riya     shah  full_time employee  administration    5   10000
# 3     yash    batia  part_time employee       technical    7   20000
# 4  siddini     khan  full_time employee       technical    6    4000
#                                       mean
#                                     salary
# type               department
# full_time employee administration  15000.0
#                    technical        4000.0
# intern             technical        5000.0
# part_time employee technical       20000.0
#                                       mean    sum
#                                     salary salary
# type               department
# full_time employee administration  15000.0  30000
#                    technical        4000.0   4000
# intern             technical        5000.0   5000
# part_time employee technical       20000.0  20000
#                     count
#                    salary
# type
# full_time employee      3
# intern                  1
# part_time employee      1
#                             std
#                          salary
# type
# full_time employee  8082.903769
