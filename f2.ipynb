# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshatpoojary11/raksha/blob/main/f2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=["hello","world","true"]
list2=range(10)
print(list1)
print(list2)
print(list1[2])
print(list[2:5])
print(list2[-3])
# Out:
# ['hello', 'world', 'true']
# range(0, 10)
# true
# list[slice(2, 5, None)]
# 7
